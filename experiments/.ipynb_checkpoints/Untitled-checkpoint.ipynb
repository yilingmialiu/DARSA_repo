# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf

# %%
for event in tf.train.summary_iterator('/datacommons/carlsonlab/yl407/work_office_home/TVT/TVT/logs/office-home/rc/events.out.tfevents.1683838936.dcc-carlsonlab-gpu-12.1812375.0'):
    for value in event.summary.value:
        print(value.tag)
        #if value.HasField('simple_value'):
        #    print(value.simple_value)
# Out:
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# train/loss_ad_global
# train/loss_ad_local
# train/loss_rec
# train/loss_im
# train/lr
# train/loss
# train/loss_clc
# ...

# %%
event
# Out:
# wall_time: 1683842638.422834
# step: 4999
# summary {
#   value {
#     tag: "train/lr"
#     simple_value: 3.6554087534668156e-10
#   }
# }
